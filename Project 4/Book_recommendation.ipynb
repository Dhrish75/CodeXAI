# %%
import pandas as pd

# %%
books_df = pd.read_csv('/content/books-dataset-2.csv')

# %%
def search_books(keyword):
  keyword = keyword.lower()
  results = books_df[
      books_df['title'].str.lower().str.contains(keyword) |
      books_df['authors'].str.lower().str.contains(keyword) |
      books_df['publisher'].str.lower().str.contains(keyword)
  ]
  return results

def display_books(books):
  if books.empty:
    print("No books found")
  else:
    for index, book in books.iterrows():
      print(f"Title: {book['title']}")
      print(f"Author: {book['authors']}")
      print(f"Average Rating: {book['average_rating']}")
      print(f"ISBN: {book['isbn']}")
      print(f"ISBN13: {book['isbn13']}")
      print(f"Language: {book['language_code']}")

      if 'num_pages' in books:
        print(f"Number of Pages: {book['num_pages']}")
        print(f"Ratings Count: {book['ratings_count']}")
        print(f"Text Reviews Count: {book['text_reviews_count']}")
        print(f"Publication Date: {book['publication_date']}")
        print(f"Publisher: {book['publisher']}")
        print('-' + 40)

def main():
  print("Welcome to the Book Recommendation Program!")
  keyword = input("Enter a keyword to search for books: ")
  results = search_books(keyword)
  display_books(results)

if __name__ == "__main__":
  main()
# Out:
# Welcome to the Book Recommendation Program!
# Enter a keyword to search for books: Douglas Adams
# Title: The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5)
# Author: Douglas Adams
# Average Rating: 4.38
# ISBN: 517226952
# ISBN13: 9.78052E+12
# Language: eng
# Title: The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)
# Author: Douglas Adams
# Average Rating: 4.38
# ISBN: 345453743
# ISBN13: 9.78035E+12
# Language: eng
# Title: The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)
# Author: Douglas Adams
# Average Rating: 4.22
# ISBN: 1400052920
# ISBN13: 9.7814E+12
# Language: eng
# Title: The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)
# Author: Douglas Adams/Stephen Fry
# Average Rating: 4.22
# ISBN: 739322206
# ISBN13: 9.78074E+12
# Language: eng
# Title: The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)
# Author: Douglas Adams
# Average Rating: 4.38
# ISBN: 517149257
# ISBN13: 9.78052E+12
# Language: eng
# Title: The Long Dark Tea-Time of the Soul (Dirk Gently  #2)
# Author: Douglas Adams
# Average Rating: 4.06
# ISBN: 671742515
# ISBN13: 9.78067E+12
# Language: en-US
# Title: The Salmon of Doubt (Dirk Gently  #3)
# Author: Douglas Adams
# Average Rating: 3.93
# ISBN: 345455290
# ISBN13: 9.78035E+12
# Language: eng
# Title: Wish You Were Here: The Official Biography of Douglas Adams
# Author: Nick  Webb
# Average Rating: 4.14
# ISBN: 345476514
# ISBN13: 9.78035E+12
# Language: eng
# Title: Douglas Adams's Starship Titanic
# Author: Terry Jones
# Average Rating: 3.6
# ISBN: 345368436
# ISBN13: 9.78035E+12
# Language: eng
# Title: Salmon of Doubt: Hitchhiking the Galaxy One Last Time
# Author: Douglas Adams/Christopher Cerf
# Average Rating: 3.93
# ISBN: 1417622857
# ISBN13: 9.78142E+12
# Language: eng
# Title: The Deeper Meaning of Liff
# Author: Douglas Adams/John Lloyd
# Average Rating: 3.93
# ISBN: 307236013
# ISBN13: 9.78031E+12
# Language: eng
# Title: Dirk Gently's Holistic Detective Agency (Dirk Gently #1)
# Author: Douglas Adams
# Average Rating: 3.98
# ISBN: 1597770078
# ISBN13: 9.7816E+12
# Language: eng
# Title: Life  the Universe and Everything (Hitchhiker's Guide to the Galaxy  #3)
# Author: Douglas Adams
# Average Rating: 4.2
# ISBN: 345418905
# ISBN13: 9.78035E+12
# Language: eng
# Title: So Long  and Thanks for All the Fish (Hitchhiker's Guide to the Galaxy  #4)
# Author: Douglas Adams
# Average Rating: 4.09
# ISBN: 330491237
# ISBN13: 9.78033E+12
# Language: eng
# Title: The Restaurant at the End of the Universe (The Hitchhiker's Guide to the Galaxy  #2)
# Author: Douglas Adams/Martin  Freeman
# Average Rating: 4.22
# ISBN: 739332074
# ISBN13: 9.78074E+12
# Language: eng
# Title: The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)
# Author: Douglas Adams
# Average Rating: 4.22
# ISBN: 330491199
# ISBN13: 9.78033E+12
# Language: eng
# Title: The Illustrated Hitchhiker's Guide To The Galaxy
# Author: Douglas Adams
# Average Rating: 4.35
# ISBN: 517599244
# ISBN13: 9.78052E+12
# Language: eng
# Title: The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide  #1)
# Author: Douglas Adams
# Average Rating: 4.22
# ISBN: 1400052939
# ISBN13: 9.7814E+12
# Language: eng
# Title: The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)
# Author: Douglas Adams
# Average Rating: 4.22
# ISBN: 671746065
# ISBN13: 9.78067E+12
# Language: eng
# Title: The Hitchhiker's Guide to the Galaxy: The Quintessential Phase (Hitchhiker's Guide: Radio Play  #5)
# Author: Douglas Adams/Dirk Maggs/Simon  Jones/Geoffrey McGivern/Mark Wing-Davey/Susan  Sheridan/Sandra Dickinson/Stephen  Moore/William Franklyn/Rula Lenska/Sam  Burke
# Average Rating: 4.37
# ISBN: 563504072
# ISBN13: 9.78056E+12
# Language: eng
# Title: The More Than Complete Hitchhiker's Guide (Hitchhiker's Guide  #1-4 + short story)
# Author: Douglas Adams
# Average Rating: 4.58
# ISBN: 681403225
# ISBN13: 9.78068E+12
# Language: en-US
# Title: Hitchhiker's Guide To The Galaxy: The Filming of the Douglas Adams classic
# Author: Robbie Stamp/Paul Simpson
# Average Rating: 3.9
# ISBN: 155704676X
# ISBN13: 9.78156E+12
# Language: eng
# Title: The Anthology at the End of the Universe: Leading Science Fiction Authors on Douglas Adams' The Hitchhiker's Guide to the Galaxy
# Author: Glenn Yeffeth/Don DeBrandt/Cory Doctorow/Bruce Bethke/Adam Roberts/Lawrence Watt-Evans/Selina Rosen/Mark W. Tiedemann/Jacqueline Carey/Susan Sizemore/Vox Day/Stephen Baxter/A.M. Dellamonica/Marguerite Krause/John Shirley/Adam-Troy Castro/Amy Berner/Maria  Alexander/Marie-Catherine Caillava/Mike Byrne
# Average Rating: 3.86
# ISBN: 1932100563
# ISBN13: 9.78193E+12
# Language: eng
